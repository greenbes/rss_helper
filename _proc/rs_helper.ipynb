# %% [raw]
# ---
# description: Fill in a module description here
# output-file: rs_helper.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# ### foo
#
# >      foo ()

# %% [markdown]
# **The nbdev export should be at the end of the file**

# %%
print("Done")
# Out:
# Done
